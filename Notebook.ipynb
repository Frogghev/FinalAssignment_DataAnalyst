# %% [markdown]
# Before starting hte project let's connect to the github repository

# %% [markdown]
# Now that the account is connected, let's start by importing the right libraries and gathering the data.
# The first data is about traffick accident, available as a json at this address

# %%
import requests

traffick_accidents_url = "https://esploradati.istat.it/SDMXWS/rest/data/41_983"
